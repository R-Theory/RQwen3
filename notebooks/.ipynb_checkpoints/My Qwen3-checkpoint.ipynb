# %%
import sys
sys.path.insert(0, "..")

import torch
import torch.nn as nn
from transformers import AutoModelForCausalLM, AutoTokenizer, AutoConfig
from src.utils import get_device, print_model_summary, format_param_count

import numpy as np
import pandas as pd

device = get_device()
summary = np.array([f"Using device: {device}",f"Using device: {device}",f"PyTorch version: {torch.__version__}"])

# %%
class TextGenerationPipeline():
    def __init__(self, d_model):
        super.__init__()
        self.tokenizer = ModelTokenizer()
        
class ModelTokenizer(nn.Modual):
    def __init__(self, d_model):
        super.__init__()
        self.byte_pair = AutoTokenizer.from_pretrained("Qwen/Qwen3-1.7B")
        pass

    def encode(x):
        pass
    def decode(x):
        pass
    def __call__():
        

class Qwen3ForCausalLM(nn.Modual):
    def __init__(self, d_model):
        super.__init__()

class TextGenaration():
    def __init__(self):
      pass

class Qwen3Model():
    def __init__(self):
        pass
    
class Qwen3PreProcessing():
    def __init__(self):
        pass
# Out:
#   Cell In[3], line 19
#     class Qwen3ForCausalLM(nn.Modual):
#                                       ^
# IndentationError: expected an indented block after function definition on line 16

# %%
class Qwen3R(nn.Module):
    def __init__(self, config):
        self.embed_tokens = nn.Embedding(
            config.vocab_size,
            config.hidden_size
        )

# %%
config_06B = AutoConfig.from_pretrained("Qwen/Qwen3-0.6B")
json_config_06B = config_06B.to_json_string()

# %%
output = Qwen3R(config=config_06B)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 output = Qwen3R(config=config_06B)
#
# Cell In[15], line 3, in Qwen3R.__init__(self, config)
#       2 def __init__(self, config):
# ----> 3     self.embed_tokens = nn.Embedding(
#       4         config.vocab_size,
#       5         config.hidden_size
#       6     )
#
# File ~/Library/Mobile Documents/com~apple~CloudDocs/treese/Projects (Cloud)/Study Grounds/.venv/lib/python3.13/site-packages/torch/nn/modules/module.py:2002, in Module.__setattr__(self, name, value)
#    2000 if isinstance(value, Module):
#    2001     if modules is None:
# -> 2002         raise AttributeError(
#    2003             "cannot assign module before Module.__init__() call"
#    2004         )
#    2005     remove_from(
#    2006         self.__dict__,
#    2007         self._parameters,
#    2008         self._buffers,
# ...
