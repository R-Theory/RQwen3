# %%
import sys
sys.path.insert(0, "..")

import torch
from src import CoreConfig, PipeLine
from src.utils import get_device

# %%
def main(message: str) -> str:
    config = CoreConfig()
    pipeline = PipeLine(config)
    print(f"Using device: {get_device()}")
    print(f"PyTorch version: {torch.__version__}")
    output = pipeline(message)
    return output


main("Why is math so important?")
# Out:
# Using device: mps
# PyTorch version: 2.10.0
# ' stdout.hw fingerprints遊びすぐに Individual'
